# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
lung = np.load("lung.npy")

# %%
lung.shape
# Out:
# (512, 512, 241)

# %%
slice = lung[:, :, 120]

# %%
slice -= slice.min()
slice = slice / slice.max() * 255

# %%
plt.imshow(slice, 'gray')

# %%
plt.show()
